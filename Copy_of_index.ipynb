# %% [markdown]
# <center><img src="https://github.com/DACSS-Spatial/data_forSpatial/raw/main/logo.png" width="700"></center>
#
# <a target="_blank" href="https://colab.research.google.com/github/DACSS-Spatial/The-Thematics/blob/main/index.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # The Thematic map
#
# Last session we created a file with several layers:

# %%
import geopandas as gpd

linkGit='https://github.com/Spatial-Data-Analytics-2025/Week3-Thematic-Maps/raw/refs/heads/main/'
linkWorldMaps='worldMaps.gpkg'

# %% [markdown]
# We can easily find out the layers in that geopackage file (**worldMaps.gpkg**):

# %%
gpd.list_layers(linkGit+linkWorldMaps)
# Out:
#         name    geometry_type
# 0     rivers  MultiLineString
# 1     cities            Point
# 2  countries     MultiPolygon

# %% [markdown]
# For the thematics we will retrieve only one layer (map):

# %%
countries=gpd.read_file(linkGit+linkWorldMaps,layer='countries')

# see some
countries
# Out:
#                    COUNTRY                                           geometry
# 0      Aruba (Netherlands)  MULTIPOLYGON (((-69.88223 12.41111, -69.94695 ...
# 1      Antigua and Barbuda  MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 2              Afghanistan  MULTIPOLYGON (((61.27656 35.60725, 61.29638 35...
# 3                  Algeria  MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# 4               Azerbaijan  MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# ..                     ...                                                ...
# 247            South Sudan  MULTIPOLYGON (((34.21807 9.96458, 34.20722 9.9...
# 248              Indonesia  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
# 249             East Timor  MULTIPOLYGON (((124.41824 -9.3001, 124.40446 -...
# 250  Curacao (Netherlands)  MULTIPOLYGON (((-68.96556 12.19889, -68.91196 ...
# 251  Bonaire (Netherlands)  MULTIPOLYGON (((-68.19736 12.22264, -68.19292 ...
#
# [252 rows x 2 columns]

# %% [markdown]
# As you see, the GDF above has just two colums; enough to plot a map, but no more than that.
#
# Let me open a DF:

# %%
import pandas as pd

someDataLink='some_dataworld.csv'

someData=pd.read_csv(linkGit+someDataLink)

## data available
someData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       172 non-null    object
#  1   iso2          171 non-null    object
#  2   iso3          172 non-null    object
#  3   region        172 non-null    object
#  4   fragility     172 non-null    float64
#  5   co2           172 non-null    int64
#  6   sq_km         172 non-null    int64
#  7   num_airports  172 non-null    int64
#  8   population    172 non-null    int64
#  9   mobiles       172 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 13.6+ KB

# %% [markdown]
# ## Pre Processing: Merging

# %% [markdown]
# The DF has some interesting numerical data (_float64_):
# * fragility: fragility index 2023 -[details here](https://fragilestatesindex.org/2023/06/14/fragile-states-index-2023-annual-report/)
# * co2: metric tonnes of CO2 emmitted -[details here](https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison/)
# * sq_km: country area -[details here](https://www.cia.gov/the-world-factbook/field/area/country-comparison/)
# * num_airports: count of airports in the country -[details here](https://www.cia.gov/the-world-factbook/field/airports/country-comparison/)
# * population: country population  -[details here](https://www.cia.gov/the-world-factbook/field/population/country-comparison/)
# * mobiles: total number of mobile cellular telephone subscribers -[details here](https://www.cia.gov/the-world-factbook/field/telephones-mobile-cellular/country-comparison/)
#
# There are also other columns that may be of help:

# %%
someData.head()
# Out:
#                Country iso2 iso3                             region  \
# 0          AFGHANISTAN   AF  AFG                         SOUTH ASIA
# 1              ALBANIA   AL  ALB                             EUROPE
# 2              ALGERIA   DZ  DZA                             AFRICA
# 3               ANGOLA   AO  AGO                             AFRICA
# 4  ANTIGUA AND BARBUDA   AG  ATG  CENTRAL AMERICA AND THE CARIBBEAN
#
#    fragility        co2    sq_km  num_airports  population   mobiles
# 0      105.0    7893000   652230            68    40121552  23000000
# 1       58.9    3794000    28748             3     3107100   2610000
# 2       75.4  151633000  2381740            95    47022473  51500000
# 3       87.8   19362000  1246700           107    37202061  25700000
# 4       54.4     729000      443             4      102634    184000

# %% [markdown]
# Preparing thematic maps requires **social data** about the geometry (line, polygon, point). The "countries" geoDF has no social data, so the preprocessing requires merging the DF into the GDF.
#
# Merging is not a trivial process. For this case, it will even require fuzzy merging. You may see the full mergin process in this [GoogleColab notebook](https://colab.research.google.com/drive/1iGTr8z1Bo8sitgg7uNcKh33pwleymb8O?usp=sharing).
#
# We will use the file produced by that colab notebook

# %%
linkToIndicators="https://github.com/Spatial-Data-Analytics-2025/Week3-Thematic-Maps/raw/refs/heads/main/worldindicators.json"
theMapAndData=gpd.read_file(linkToIndicators)
theMapAndData.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 172 entries, 0 to 171
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       172 non-null    object
#  1   iso2          171 non-null    object
#  2   iso3          172 non-null    object
#  3   region        172 non-null    object
#  4   fragility     172 non-null    float64
#  5   co2           172 non-null    int64
#  6   sq_km         172 non-null    int32
#  7   num_airports  172 non-null    int32
#  8   population    172 non-null    int32
#  9   mobiles       172 non-null    int32
#  10  geometry      172 non-null    geometry
# dtypes: float64(1), geometry(1), int32(4), int64(1), object(4)
# memory usage: 12.2+ KB

# %%
theMapAndData
# Out:
#                  Country iso2 iso3                             region  \
# 0    ANTIGUA AND BARBUDA   AG  ATG  CENTRAL AMERICA AND THE CARIBBEAN
# 1            AFGHANISTAN   AF  AFG                         SOUTH ASIA
# 2                ALGERIA   DZ  DZA                             AFRICA
# 3             AZERBAIJAN   AZ  AZE                        MIDDLE EAST
# 4                ALBANIA   AL  ALB                             EUROPE
# ..                   ...  ...  ...                                ...
# 167               ZAMBIA   ZM  ZMB                             AFRICA
# 168             ZIMBABWE   ZW  ZWE                             AFRICA
# 169          SOUTH SUDAN   SS  SSD                             AFRICA
# 170            INDONESIA   ID  IDN            EAST AND SOUTHEAST ASIA
# 171           EAST TIMOR   TL  TLS            EAST AND SOUTHEAST ASIA
#
#      fragility        co2    sq_km  num_airports  population    mobiles  \
# 0         54.4     729000      443             4      102634     184000
# 1        105.0    7893000   652230            68    40121552   23000000
# 2         75.4  151633000  2381740            95    47022473   51500000
# 3         73.2   35389000    86600            32    10650239   11000000
# 4         58.9    3794000    28748             3     3107100    2610000
# ..         ...        ...      ...           ...         ...        ...
# 167       85.7    6798000   752618           120    20799116   21200000
# 168       99.5    7902000   390757           144    17150352   15000000
# 169      112.2    1778000   644329            89    12703714    6170000
# 170       70.4  563543000  1904569           556   281562465  352000000
# 171       85.5     538000    14874            11     1506909    1560000
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.73889 17.54055, -61.75195 ...
# 1    MULTIPOLYGON (((61.27656 35.60725, 61.29638 35...
# 2    MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# 3    MULTIPOLYGON (((46.54037 38.87559, 46.49554 38...
# 4    MULTIPOLYGON (((20.79192 40.43154, 20.78722 40...
# ..                                                 ...
# 167  MULTIPOLYGON (((30.21302 -14.98172, 30.21917 -...
# 168  MULTIPOLYGON (((32.48888 -21.34445, 32.46541 -...
# 169  MULTIPOLYGON (((34.21807 9.96458, 34.20722 9.9...
# 170  MULTIPOLYGON (((123.21846 -10.80917, 123.19832...
# 171  MULTIPOLYGON (((124.41824 -9.3001, 124.40446 -...
#
# [172 rows x 11 columns]

# %% [markdown]
# As you see, the columns from the DF (someData) are now part of the GDF (countries), that is now in this new GDF **theMapAndData**.

# %% [markdown]
# # Thematics: the DDM (Dot Density Map)
#
# You have a DDM if you use **dots** to show comparatively which polygon of a map has 'more' (or 'less') of some countable phenomenon of interest.
# A dot is an aggregated value, but it is constant for each dot.
#
# We have the world map, let's see the regions we have:

# %%
theMapAndData.region.value_counts()
# Out:
# region
# AFRICA                               52
# EUROPE                               37
# MIDDLE EAST                          16
# CENTRAL AMERICA AND THE CARIBBEAN    16
# EAST AND SOUTHEAST ASIA              15
# SOUTH AMERICA                        12
# SOUTH ASIA                            8
# AUSTRALIA AND OCEANIA                 7
# CENTRAL ASIA                          6
# NORTH AMERICA                         3
# Name: count, dtype: int64

# %% [markdown]
# ### Preprocessing: Filtering
#
# Let's keep Africa for this session:

# %%
Africa=theMapAndData[theMapAndData.region=='AFRICA']
Africa.plot()
# Out:
# <Axes: >

# %% [markdown]
# **What variable to use?** Let's go with population (countable).
#
# A DDM can serve as an effective way to show the distribution of people. The most critical tasks are:
#
# * Unit per Dot: Deciding how many people each dot should represent is key for visual clarity. This value should be chosen carefully to avoid oversaturation or sparsity.
#
# * Dot Placement: The dots should be randomly distributed within each polygon to avoid misrepresenting the data.
#
# Every dot represents the same amount, then a DDM uses raw counts (non-normalized). The size of all dots on the map are the same, which  ensures a consistent visual comparison.

# %% [markdown]
# ### Preprocessing: NEW UNIT
#
# How many people will the dot represent? There is some **trial and error** to make this decision, but it helps exploring the variable descriptives.

# %%
print(Africa.population.describe().to_string(float_format=lambda x: f'{x:.0f}'))
# Out:
# count          52
# mean     28193457
# std      41102292
# min         98187
# 25%       2733577
# 50%      14341616
# 75%      33660488
# max     236747130

# %% [markdown]
# From what we see, we should not choose 100 000 as the unit per dot. At least one country will have zero dots. Then, the trial and error is about choosing values like 1000, 10000, 20000, etc., but below 98187.
#
# If we chose 25000, this would be the amount of points within each polygon (country):

# %%
(Africa.set_index("Country").population / 25000).astype(int).sort_values()
# Out:
# Country
# SEYCHELLES                             3
# SAO TOME AND PRINCIPE                  8
# CAPE VERDE                            24
# COMOROS                               36
# DJIBOUTI                              39
# ESWATINI                              45
# MAURITIUS                             52
# EQUATORIAL GUINEA                     71
# GUINEA-BISSAU                         85
# LESOTHO                               89
# BOTSWANA                              98
# GABON                                 98
# GAMBIA                               100
# NAMIBIA                              112
# MAURITANIA                           173
# LIBERIA                              217
# CENTRAL AFRICAN REPUBLIC             226
# CONGO                                243
# LIBYA                                294
# TOGO                                 356
# SIERRA LEONE                         364
# TUNISIA                              481
# SOUTH SUDAN                          508
# BURUNDI                              543
# RWANDA                               544
# GUINEA                               559
# BENIN                                587
# ZIMBABWE                             686
# SENEGAL                              753
# CHAD                                 763
# ZAMBIA                               831
# MALAWI                               870
# MALI                                 879
# BURKINA FASO                         921
# NIGER                               1053
# MADAGASCAR                          1178
# IVORY COAST                         1199
# CAMEROON                            1238
# MOZAMBIQUE                          1334
# GHANA                               1383
# ANGOLA                              1488
# MOROCCO                             1495
# ALGERIA                             1880
# UGANDA                              1971
# SUDAN                               2018
# KENYA                               2329
# SOUTH AFRICA                        2417
# TANZANIA                            2698
# EGYPT                               4449
# DEMOCRATIC REPUBLIC OF THE CONGO    4616
# ETHIOPIA                            4742
# NIGERIA                             9469
# Name: population, dtype: int64

# %% [markdown]
# This is a safe option (no zeroes).

# %% [markdown]
# ### Preprocessing: NEW LAYER
#
# We need to create a map of dots, a new layer. The source will be the Africa polygons we currently have. Let's do that first:

# %%
# a copy of Africa
temporal_gdf=Africa.copy()
temporal_gdf.head()
# Out:
#      Country iso2 iso3  region  fragility        co2    sq_km  num_airports  \
# 2    ALGERIA   DZ  DZA  AFRICA       75.4  151633000  2381740            95
# 6     ANGOLA   AO  AGO  AFRICA       87.8   19362000  1246700           107
# 12  BOTSWANA   BW  BWA  AFRICA       59.5    5965000   581730           122
# 19     BENIN   BJ  BEN  AFRICA       73.6    6903000   112622            10
# 26   BURUNDI   BI  BDI  AFRICA       98.2     715000    27830             6
#
#     population   mobiles                                           geometry
# 2     47022473  51500000  MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# 6     37202061  25700000  MULTIPOLYGON (((13.09139 -4.63306, 13.09264 -4...
# 12     2450668   4440000  MULTIPOLYGON (((26.40114 -24.63189, 26.38996 -...
# 19    14697052  16400000  MULTIPOLYGON (((2.73295 7.65821, 2.73222 7.651...
# 26    13590102   8650000  MULTIPOLYGON (((30.84366 -2.97879, 30.83723 -2...

# %% [markdown]
# the GeoDF **temporal_gdf** is just an independent copy of Africa, as you see all the geometries are MULTIPOLYGONS still. Let me replace the row names by the country name:

# %%
# the row names will be the country
temporal_gdf.set_index('Country',inplace=True)

# we have this now
temporal_gdf.head()
# Out:
#          iso2 iso3  region  fragility        co2    sq_km  num_airports  \
# Country
# ALGERIA    DZ  DZA  AFRICA       75.4  151633000  2381740            95
# ANGOLA     AO  AGO  AFRICA       87.8   19362000  1246700           107
# BOTSWANA   BW  BWA  AFRICA       59.5    5965000   581730           122
# BENIN      BJ  BEN  AFRICA       73.6    6903000   112622            10
# BURUNDI    BI  BDI  AFRICA       98.2     715000    27830             6
#
#           population   mobiles  \
# Country
# ALGERIA     47022473  51500000
# ANGOLA      37202061  25700000
# BOTSWANA     2450668   4440000
# BENIN       14697052  16400000
# BURUNDI     13590102   8650000
#
#                                                    geometry
# Country
# ALGERIA   MULTIPOLYGON (((-5.15213 30.18047, -5.13917 30...
# ANGOLA    MULTIPOLYGON (((13.09139 -4.63306, 13.09264 -4...
# BOTSWANA  MULTIPOLYGON (((26.40114 -24.63189, 26.38996 -...
# BENIN     MULTIPOLYGON (((2.73295 7.65821, 2.73222 7.651...
# BURUNDI   MULTIPOLYGON (((30.84366 -2.97879, 30.83723 -2...

# %% [markdown]
# Let's create **dots_per_country**, the column that represents the amount of dots for each country (like we saw before):

# %%
# creating  column
temporal_gdf['dots_per_country'] = (Africa['population'] / 25000).astype(int).values # notice .values!

# see
temporal_gdf['dots_per_country'].head(10)
# Out:
# Country
# ALGERIA                             1880
# ANGOLA                              1488
# BOTSWANA                              98
# BENIN                                587
# BURUNDI                              543
# CHAD                                 763
# CONGO                                243
# DEMOCRATIC REPUBLIC OF THE CONGO    4616
# CAMEROON                            1238
# COMOROS                               36
# Name: dots_per_country, dtype: int64

# %% [markdown]
# Let's find a **random_location** for the dots:

# %%
# enter 'sample_points()'
temporal_gdf.sample_points(size=temporal_gdf['dots_per_country'],rng=123).head(10)
# Out:
# Country
# ALGERIA                             MULTIPOINT ((-8.64514 27.70401), (-8.59924 27....
# ANGOLA                              MULTIPOINT ((12.0628 -16.71525), (12.10423 -15...
# BOTSWANA                            MULTIPOINT ((20.26153 -24.22378), (20.36865 -2...
# BENIN                               MULTIPOINT ((0.81304 10.57673), (0.84972 10.65...
# BURUNDI                             MULTIPOINT ((29.03506 -2.79301), (29.03678 -2....
# CHAD                                MULTIPOINT ((13.5274 14.43927), (13.61895 14.0...
# CONGO                               MULTIPOINT ((11.34861 -3.61575), (11.41961 -3....
# DEMOCRATIC REPUBLIC OF THE CONGO    MULTIPOINT ((12.4375 -5.8711), (12.44332 -5.79...
# CAMEROON                            MULTIPOINT ((8.54056 4.62486), (8.61714 4.8168...
# COMOROS                             MULTIPOINT ((43.22178 -11.76054), (43.25128 -1...
# Name: sampled_points, dtype: geometry

# %% [markdown]
# That was a critical step, you created a...

# %%
type(temporal_gdf.sample_points(size=temporal_gdf['dots_per_country'],rng=123))
# Out:
# geopandas.geoseries.GeoSeries

# %% [markdown]
# Take a look at one of this series' element:

# %%
# this is the case of Comoros:
temporal_gdf.sample_points(size=temporal_gdf['dots_per_country'],rng=123).loc['COMOROS']
# Out:
# <MULTIPOINT ((43.222 -11.761), (43.251 -11.602), (43.254 -11.646), (43.285 -...>

# %% [markdown]
# As usual, that GeoS is turned into a GeoDF:

# %%
Africa_dots=gpd.GeoDataFrame(geometry=temporal_gdf.sample_points(size=temporal_gdf['dots_per_country'],rng=123))
Africa_dots.head(10)
# Out:
#                                                                            geometry
# Country
# ALGERIA                           MULTIPOINT ((-8.64514 27.70401), (-8.59924 27....
# ANGOLA                            MULTIPOINT ((12.0628 -16.71525), (12.10423 -15...
# BOTSWANA                          MULTIPOINT ((20.26153 -24.22378), (20.36865 -2...
# BENIN                             MULTIPOINT ((0.81304 10.57673), (0.84972 10.65...
# BURUNDI                           MULTIPOINT ((29.03506 -2.79301), (29.03678 -2....
# CHAD                              MULTIPOINT ((13.5274 14.43927), (13.61895 14.0...
# CONGO                             MULTIPOINT ((11.34861 -3.61575), (11.41961 -3....
# DEMOCRATIC REPUBLIC OF THE CONGO  MULTIPOINT ((12.4375 -5.8711), (12.44332 -5.79...
# CAMEROON                          MULTIPOINT ((8.54056 4.62486), (8.61714 4.8168...
# COMOROS                           MULTIPOINT ((43.22178 -11.76054), (43.25128 -1...

# %% [markdown]
# Now you have a GDF:

# %%
Africa_dots.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 52 entries, ALGERIA to SOUTH SUDAN
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  52 non-null     geometry
# dtypes: geometry(1)
# memory usage: 2.9+ KB

# %% [markdown]
# Here is our DDM:

# %%
base=Africa.plot(facecolor="white",#color of polygon fill
               edgecolor='grey') #color of border
Africa_dots.plot(markersize=0.02, color='red',ax=base, alpha=0.2)
# Out:
# <Axes: >

# %% [markdown]
# It is generally recommended that DDMs use an **equal-area projection**, which benefits density and limits area distortion.

# %%
Africa_8857=Africa.to_crs(8857)
Africa_dots_8857=Africa_dots.to_crs(8857)

# %%
# new version
base=Africa_8857.plot(facecolor="white",
                              edgecolor='grey')
Africa_dots_8857.plot(markersize=0.02, color='red',ax=base, alpha=0.2)
# Out:
# <Axes: >

# %% [markdown]
# ### Exporting to R?
#
# Africa_dots_8857 has a column of multi-points as we know. Shapefiles can not deal with this structure not visual programs in R such as **leaflet**. Then, we need to split those multipoints using **explode()**:

# %%
Africa_dots_8857.explode()
# Out:
#                                     geometry
# Country
# ALGERIA      POINT (-782809.218 3488777.019)
# ALGERIA       POINT (-778027.472 3512073.46)
# ALGERIA      POINT (-779432.711 3451352.477)
# ALGERIA      POINT (-771626.784 3559137.523)
# ALGERIA      POINT (-771462.039 3553365.068)
# ...                                      ...
# SOUTH SUDAN   POINT (3391531.359 659742.661)
# SOUTH SUDAN   POINT (3411569.233 603593.798)
# SOUTH SUDAN   POINT (3410938.404 648228.346)
# SOUTH SUDAN   POINT (3411422.201 658166.544)
# SOUTH SUDAN    POINT (3422935.28 659421.477)
#
# [58615 rows x 1 columns]

# %% [markdown]
# We may just need to get rid of the indexes:

# %%
Africa_dots_8857.explode(ignore_index=True)
# Out:
#                               geometry
# 0      POINT (-782809.218 3488777.019)
# 1       POINT (-778027.472 3512073.46)
# 2      POINT (-779432.711 3451352.477)
# 3      POINT (-771626.784 3559137.523)
# 4      POINT (-771462.039 3553365.068)
# ...                                ...
# 58610   POINT (3391531.359 659742.661)
# 58611   POINT (3411569.233 603593.798)
# 58612   POINT (3410938.404 648228.346)
# 58613   POINT (3411422.201 658166.544)
# 58614    POINT (3422935.28 659421.477)
#
# [58615 rows x 1 columns]

# %% [markdown]
# The function **explodes()** returns...

# %%
type(Africa_dots_8857.explode(ignore_index=True))
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# This is a safe option outside Python:

# %%
# then
Africa_dots_8857=Africa_dots_8857.explode(ignore_index=True)

# %% [markdown]
# # Thematics: the PSM (Proportional Symbol Map)
#
# You have a PSM if you use a symbol (generally a circle) to show the distribution of a variable per location.
# The symbol is an aggregated raw value, and its size varies according to those values. So now we need:

# %% [markdown]
# ### Preprocessing: scale the variable to determine size
#
# How to adjust the size of a symbols based of population? We should not have symbol size five million!

# %%
##what about square root scaling
import numpy as np

max_size=40
min_size=1
scaled_sizes = np.sqrt(
    (Africa_8857.population - Africa_8857.population.min()) / (Africa_8857.population.max() - Africa_8857.population.min())
) * (max_size-1) + min_size

scaled_sizes.sort_values()
# Out:
# 133     1.000000
# 149     1.897669
# 42      2.815506
# 36      3.270320
# 45      3.400805
# 165     3.585286
# 102     3.791389
# 50      4.303209
# 126     4.615784
# 92      4.699448
# 12      4.888440
# 59      4.892105
# 58      4.948033
# 163     5.169980
# 103     6.214047
# 91      6.857938
# 40      6.974027
# 31      7.209678
# 94      7.832390
# 148     8.529079
# 137     8.615256
# 150     9.764119
# 169    10.001043
# 26     10.312132
# 131    10.323582
# 66     10.447830
# 19     10.686611
# 168    11.468925
# 135    11.977545
# 29     12.049348
# 167    12.534725
# 98     12.800296
# 100    12.862035
# 158    13.143587
# 111    13.987701
# 95     14.735671
# 77     14.858894
# 35     15.085296
# 110    15.619288
# 61     15.888969
# 6      16.442654
# 101    16.481214
# 2      18.366454
# 154    18.779847
# 141    18.992619
# 82     20.332162
# 134    20.693868
# 153    21.807794
# 48     27.727924
# 32     28.223007
# 53     28.592035
# 112    40.000000
# Name: population, dtype: float64

# %% [markdown]
# ### Preprocessing: create new layer
#
# Similar to DDM, the PSM is a new layer, built from the original polygons:

# %%
Africa_8857_symbols = Africa_8857.copy()
Africa_8857_symbols.set_index('Country',inplace=True)

#this is just a copy (new index names)
Africa_8857_symbols.head()
# Out:
#          iso2 iso3  region  fragility        co2    sq_km  num_airports  \
# Country
# ALGERIA    DZ  DZA  AFRICA       75.4  151633000  2381740            95
# ANGOLA     AO  AGO  AFRICA       87.8   19362000  1246700           107
# BOTSWANA   BW  BWA  AFRICA       59.5    5965000   581730           122
# BENIN      BJ  BEN  AFRICA       73.6    6903000   112622            10
# BURUNDI    BI  BDI  AFRICA       98.2     715000    27830             6
#
#           population   mobiles  \
# Country
# ALGERIA     47022473  51500000
# ANGOLA      37202061  25700000
# BOTSWANA     2450668   4440000
# BENIN       14697052  16400000
# BURUNDI     13590102   8650000
#
#                                                    geometry
# Country
# ALGERIA   MULTIPOLYGON (((-461528.863 3785845.186, -4603...
# ANGOLA    MULTIPOLYGON (((1252211.409 -594965.255, 12523...
# BOTSWANA  MULTIPOLYGON (((2419408.33 -3115326.798, 24184...
# BENIN     MULTIPOLYGON (((260709.591 982516.929, 260641....
# BURUNDI   MULTIPOLYGON (((2952925.496 -382651.512, 29522...

# %% [markdown]
# Let's set the **size** of the symbol:

# %%
Africa_8857_symbols['size']=scaled_sizes.values # notice .values!

# %% [markdown]
# ### Preprocessing: location for the symbol
#
# We need one symbol per polygon, an obvious choice is the centroid.

# %%
# Africa_8857_locations will have a new geometry:
Africa_8857_symbols['geometry'] = Africa_8857_symbols['geometry'].centroid

# see the geom is NOW a POINT
Africa_8857_symbols
# Out:
#                                   iso2 iso3  region  fragility        co2  \
# Country
# ALGERIA                             DZ  DZA  AFRICA       75.4  151633000
# ANGOLA                              AO  AGO  AFRICA       87.8   19362000
# BOTSWANA                            BW  BWA  AFRICA       59.5    5965000
# BENIN                               BJ  BEN  AFRICA       73.6    6903000
# BURUNDI                             BI  BDI  AFRICA       98.2     715000
# CHAD                                TD  TCD  AFRICA      108.5    1771000
# CONGO                               CG  COG  AFRICA       92.5    4523000
# DEMOCRATIC REPUBLIC OF THE CONGO    CD  COD  AFRICA      110.2    2653000
# CAMEROON                            CM  CMR  AFRICA       97.0    7105000
# COMOROS                             KM  COM  AFRICA       81.7     326000
# CENTRAL AFRICAN REPUBLIC            CF  CAF  AFRICA      108.9     285000
# CAPE VERDE                          CV  CPV  AFRICA       66.6    1002000
# DJIBOUTI                            DJ  DJI  AFRICA       85.1     610000
# EGYPT                               EG  EGY  AFRICA       88.4  235137000
# EQUATORIAL GUINEA                   GQ  GNQ  AFRICA       82.6    4528000
# ETHIOPIA                            ET  ETH  AFRICA       94.2   16798000
# GAMBIA                              GM  GMB  AFRICA       83.9     606000
# GABON                               GA  GAB  AFRICA       70.5    2651000
# GHANA                               GH  GHA  AFRICA       65.9   18093000
# GUINEA                              GN  GIN  AFRICA       99.4    2981000
# IVORY COAST                         CI  CIV  AFRICA       92.1   11880000
# KENYA                               KE  KEN  AFRICA       93.5   17709000
# LIBERIA                             LR  LBR  AFRICA       90.2    1346000
# LESOTHO                             LS  LSO  AFRICA       79.7     736000
# LIBYA                               LY  LBY  AFRICA       92.2   38297000
# MADAGASCAR                          MG  MDG  AFRICA       80.9    4218000
# MALAWI                              MW  MWI  AFRICA       83.3    1542000
# MALI                                ML  MLI  AFRICA       94.5    5679000
# MOROCCO                             MA  MAR  AFRICA       73.0   60200000
# MAURITIUS                           MU  MUS  AFRICA       38.9    7191000
# MAURITANIA                          MR  MRT  AFRICA       90.1    4041000
# MOZAMBIQUE                          MZ  MOZ  AFRICA       88.7    7753000
# NIGER                               NE  NER  AFRICA       96.2    2374000
# NIGERIA                             NG  NGA  AFRICA       98.5  104494000
# GUINEA-BISSAU                       GW  GNB  AFRICA       95.5     342000
# RWANDA                              RW  RWA  AFRICA       87.5    1189000
# SEYCHELLES                          SC  SYC  AFRICA       55.2    1156000
# ESWATINI                            1520000   POINT (2865273.36 -3350438.621)
# ZAMBIA                             21200000  POINT (2629786.953 -1717186.669)
# ZIMBABWE                           15000000  POINT (2787117.299 -2416308.277)
# SOUTH SUDAN                         6170000    POINT (2891304.613 934969.388)
#
#                                        size
# Country
# ALGERIA                           18.366454
# ANGOLA                            16.442654
# BOTSWANA                           4.888440
# BENIN                             10.686611
# BURUNDI                           10.312132
# CHAD                              12.049348
# CONGO                              7.209678
# DEMOCRATIC REPUBLIC OF THE CONGO  28.223007
# CAMEROON                          15.085296
# COMOROS                            3.270320
# CENTRAL AFRICAN REPUBLIC           6.974027
# CAPE VERDE                         2.815506
# DJIBOUTI                           3.400805
# EGYPT                             27.727924
# EQUATORIAL GUINEA                  4.303209
# ETHIOPIA                          28.592035
# GAMBIA                             4.948033
# GABON                              4.892105
# GHANA                             15.888969
# GUINEA                            10.447830
# IVORY COAST                       14.858894
# KENYA                             20.332162
# LIBERIA                            6.857938
# LESOTHO                            4.699448
# LIBYA                              7.832390
# MADAGASCAR                        14.735671
# MALAWI                            12.800296
# MALI                              12.862035
# MOROCCO                           16.481214
# MAURITIUS                          3.791389
# MAURITANIA                         6.214047
# MOZAMBIQUE                        15.619288
# NIGER                             13.987701
# NIGERIA                           40.000000
# GUINEA-BISSAU                      4.615784
# RWANDA                            10.323582
# SEYCHELLES                         1.000000
# SOUTH AFRICA                      20.693868
# SENEGAL                           11.977545
# SIERRA LEONE                       8.615256
# SUDAN                             18.992619
# TOGO                               8.529079
# SAO TOME AND PRINCIPE              1.897669
# TUNISIA                            9.764119
# TANZANIA                          21.807794
# UGANDA                            18.779847
# BURKINA FASO                      13.143587
# NAMIBIA                            5.169980
# ESWATINI                           3.585286
# ZAMBIA                            12.534725
# ZIMBABWE                          11.468925
# SOUTH SUDAN                       10.001043

# %% [markdown]
# We got the basics, then:

# %%
base=Africa_8857.plot(facecolor="white",
                      edgecolor='grey')
# Plot the centroids on top
Africa_8857_symbols.plot(
    ax=base,
    markersize=Africa_8857_symbols['size'],
    color='black'
)
# Out:
# <Axes: >

# %% [markdown]
# Keep in mind that the standard way of computing centroids may bring some trouble if you have multipolygons (archipelagos?). Let´s plot Seychelles:

# %%
import folium
import mapclassify
import matplotlib.pyplot as plt

base=Africa_8857[Africa_8857.Country=="SEYCHELLES"].explore()
Africa_8857_symbols[Africa_8857_symbols.index=="SEYCHELLES"].explore(m=base,color="red")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3093a8d270ef5b1ce3d46a6599232a1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3093a8d270ef5b1ce3d46a6599232a1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3093a8d270ef5b1ce3d46a6599232a1e = L.map(
#                 &quot;map_3093a8d270ef5b1ce3d46a6599232a1e&quot;,
#                 {
#                     center: [-7.007361881616212, 50.87311935424804],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3093a8d270ef5b1ce3d46a6599232a1e);
#
#
#
#
#
#             var tile_layer_dfa50bb82f67a988c275c3bfa64edd5f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfa50bb82f67a988c275c3bfa64edd5f.addTo(map_3093a8d270ef5b1ce3d46a6599232a1e);
#
#
#             map_3093a8d270ef5b1ce3d46a6599232a1e.fitBounds(
#                 [[-9.46305655476478, 46.205688476562486], [-4.551667208467646, 55.540550231933594]],
#                 {}
#             );
#
#
#         function geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b = L.geoJson(null, {
#                 onEachFeature: geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_onEachFeature,
#
#                 style: geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_styler,
#                 pointToLayer: geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5f4e8bad60a1721ba0aef3b0f9370a9b_add (data) {
#             geo_json_5f4e8bad60a1721ba0aef3b0f9370

# %%
# %pip install folium mapclassify matplotlib
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Collecting mapclassify
#   Downloading mapclassify-2.10.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (3.5)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from mapclassify) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.8.3)
# Downloading mapclassify-2.10.0-py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 11.3 MB/s eta 0:00:00
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.10.0

# %% [markdown]
# The location is nowhere within a polygon. An  alternative is **representative_point()**:

# %%
# replace the points
Africa_8857_symbols["geometry"]=Africa_8857.representative_point().values

# %% [markdown]
# We will keep that last result.

# %%
base=Africa_8857[Africa_8857.Country=="SEYCHELLES"].explore()
Africa_8857_symbols[Africa_8857_symbols.index=="SEYCHELLES"].explore(m=base,color="red")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cdeb3ffd5a18758fe7da47b0db7a96d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cdeb3ffd5a18758fe7da47b0db7a96d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cdeb3ffd5a18758fe7da47b0db7a96d4 = L.map(
#                 &quot;map_cdeb3ffd5a18758fe7da47b0db7a96d4&quot;,
#                 {
#                     center: [-7.007361881616212, 50.87311935424804],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cdeb3ffd5a18758fe7da47b0db7a96d4);
#
#
#
#
#
#             var tile_layer_4ea186a1d09da391fb2a310da29e94e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ea186a1d09da391fb2a310da29e94e8.addTo(map_cdeb3ffd5a18758fe7da47b0db7a96d4);
#
#
#             map_cdeb3ffd5a18758fe7da47b0db7a96d4.fitBounds(
#                 [[-9.46305655476478, 46.205688476562486], [-4.551667208467646, 55.540550231933594]],
#                 {}
#             );
#
#
#         function geo_json_d7f46eef9d15217fdf379ed214d5fa50_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d7f46eef9d15217fdf379ed214d5fa50_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d7f46eef9d15217fdf379ed214d5fa50_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_d7f46eef9d15217fdf379ed214d5fa50_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d7f46eef9d15217fdf379ed214d5fa50_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d7f46eef9d15217fdf379ed214d5fa50.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d7f46eef9d15217fdf379ed214d5fa50_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d7f46eef9d15217fdf379ed214d5fa50 = L.geoJson(null, {
#                 onEachFeature: geo_json_d7f46eef9d15217fdf379ed214d5fa50_onEachFeature,
#
#                 style: geo_json_d7f46eef9d15217fdf379ed214d5fa50_styler,
#                 pointToLayer: geo_json_d7f46eef9d15217fdf379ed214d5fa50_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_d7f46eef9d15217fdf379ed214d5fa50_add (data) {
#             geo_json_d7f46eef9d15217fdf379ed214d5f

# %% [markdown]
# ### Preprocessing: detect outliers
#
# PPMs are not thematic maps to see precise values, but to reveal clear differences on the variable distribution used. As human eyes are very limited to detect area differences, we may need to use some other tactics to confirm if we have outliers:

# %%
boxplotInfo=Africa_8857_symbols.boxplot(column='population',return_type="dict")

# %% [markdown]
# The object **boxplotInfo** showed the boxplot, and we confirm there are outliers. We can recover them like this:

# %%
outliers=boxplotInfo['fliers'][0].get_ydata()
## see
outliers
# Out:
# array([115403027, 111247248, 118550298, 236747130], dtype=object)

# %% [markdown]
# Then, these are the outlying countries:

# %%
Africa_8857_symbols[Africa_8857_symbols.population.isin(outliers)].index
# Out:
# Index(['DEMOCRATIC REPUBLIC OF THE CONGO', 'EGYPT', 'ETHIOPIA', 'NIGERIA'], dtype='object', name='Country')

# %% [markdown]
# Knowing this information, we can create a column as outlier flag:

# %%
Africa_8857_symbols['population_outlier']=Africa_8857_symbols.population.isin(outliers)*1

## see
Africa_8857_symbols
# Out:
#                                   iso2 iso3  region  fragility        co2  \
# Country
# ALGERIA                             DZ  DZA  AFRICA       75.4  151633000
# ANGOLA                              AO  AGO  AFRICA       87.8   19362000
# BOTSWANA                            BW  BWA  AFRICA       59.5    5965000
# BENIN                               BJ  BEN  AFRICA       73.6    6903000
# BURUNDI                             BI  BDI  AFRICA       98.2     715000
# CHAD                                TD  TCD  AFRICA      108.5    1771000
# CONGO                               CG  COG  AFRICA       92.5    4523000
# DEMOCRATIC REPUBLIC OF THE CONGO    CD  COD  AFRICA      110.2    2653000
# CAMEROON                            CM  CMR  AFRICA       97.0    7105000
# COMOROS                             KM  COM  AFRICA       81.7     326000
# CENTRAL AFRICAN REPUBLIC            CF  CAF  AFRICA      108.9     285000
# CAPE VERDE                          CV  CPV  AFRICA       66.6    1002000
# DJIBOUTI                            DJ  DJI  AFRICA       85.1     610000
# EGYPT                               EG  EGY  AFRICA       88.4  235137000
# EQUATORIAL GUINEA                   GQ  GNQ  AFRICA       82.6    4528000
# ETHIOPIA                            ET  ETH  AFRICA       94.2   16798000
# GAMBIA                              GM  GMB  AFRICA       83.9     606000
# GABON                               GA  GAB  AFRICA       70.5    2651000
# GHANA                               GH  GHA  AFRICA       65.9   18093000
# GUINEA                              GN  GIN  AFRICA       99.4    2981000
# IVORY COAST                         CI  CIV  AFRICA       92.1   11880000
# KENYA                               KE  KEN  AFRICA       93.5   17709000
# LIBERIA                             LR  LBR  AFRICA       90.2    1346000
# LESOTHO                             LS  LSO  AFRICA       79.7     736000
# LIBYA                               LY  LBY  AFRICA       92.2   38297000
# MADAGASCAR                          MG  MDG  AFRICA       80.9    4218000
# MALAWI                              MW  MWI  AFRICA       83.3    1542000
# MALI                                ML  MLI  AFRICA       94.5    5679000
# MOROCCO                             MA  MAR  AFRICA       73.0   60200000
# MAURITIUS                           MU  MUS  AFRICA       38.9    7191000
# MAURITANIA                          MR  MRT  AFRICA       90.1    4041000
# MOZAMBIQUE                          MZ  MOZ  AFRICA       88.7    7753000
# NIGER                               NE  NER  AFRICA       96.2    2374000
# TANZANIA                           70200000   POINT (3269316.589 -817390.394)
# UGANDA                             42100000    POINT (3131336.293 175287.886)
# BURKINA FASO                       24700000   POINT (-112770.335 1566418.178)
# NAMIBIA                             2600000  POINT (1598500.435 -2893658.557)
# ESWATINI                            1520000  POINT (2862628.258 -3345570.597)
# ZAMBIA                             21200000  POINT (2407586.605 -1678163.786)
# ZIMBABWE                           15000000   POINT (2738721.618 -2417820.45)
# SOUTH SUDAN                         6170000   POINT (2780382.012 1002979.353)
#
#                                        size  population_outlier
# Country
# ALGERIA                           18.366454                   0
# ANGOLA                            16.442654                   0
# BOTSWANA                           4.888440                   0
# BENIN                             10.686611                   0
# BURUNDI                           10.312132                   0
# CHAD                              12.049348                   0
# CONGO                              7.209678                   0
# DEMOCRATIC REPUBLIC OF THE CONGO  28.223007                   1
# CAMEROON                          15.085296                   0
# COMOROS                            3.270320                   0
# CENTRAL AFRICAN REPUBLIC           6.974027                   0
# CAPE VERDE                         2.815506                   0
# DJIBOUTI                           3.400805                   0
# EGYPT                             27.727924                   1
# EQUATORIAL GUINEA                  4.303209                   0
# ETHIOPIA                          28.592035                   1
# GAMBIA                             4.948033                   0
# GABON                              4.892105                   0
# GHANA                             15.888969                   0
# GUINEA                            10.447830                   0
# IVORY COAST                       14.858894                   0
# KENYA                             20.332162                   0
# LIBERIA                            6.857938                   0
# LESOTHO                            4.699448                   0
# LIBYA                              7.832390                   0
# MADAGASCAR                        14.735671                   0
# MALAWI                            12.800296                   0
# MALI                              12.862035                   0
# MOROCCO                           16.481214                   0
# MAURITIUS                          3.791389                   0
# MAURITANIA                         6.214047                   0
# MOZAMBIQUE                        15.619288                   0
# NIGER                             13.987701                   0
# NIGERIA                           40.000000                   1
# GUINEA-BISSAU                      4.615784                   0
# RWANDA                            10.323582                   0
# SEYCHELLES                         1.000000                   0
# SOUTH AFRICA                      20.693868                   0
# SENEGAL                           11.977545                   0
# SIERRA LEONE                       8.615256                   0
# SUDAN                             18.992619                   0
# TOGO                               8.529079                   0
# SAO TOME AND PRINCIPE              1.897669                   0
# TUNISIA                            9.764119                   0
# TANZANIA                          21.807794                   0
# UGANDA                            18.779847                   0
# BURKINA FASO                      13.143587                   0
# NAMIBIA                            5.169980                   0
# ESWATINI                           3.585286                   0
# ZAMBIA                            12.534725                   0
# ZIMBABWE                          11.468925                   0
# SOUTH SUDAN                       10.001043                   0

# %% [markdown]
# We can use that like this:

# %%
base = Africa_8857.plot(color='white', edgecolor='black', figsize=(10,10))

# Define your color map
mapcolor = {1: 'red', 0: 'grey'}

# Plot the centroids on top
Africa_8857_symbols.plot(
    ax=base,
    markersize=Africa_8857_symbols['size'],
    color=Africa_8857_symbols['population_outlier'].map(mapcolor)
)
# Out:
# <Axes: >

# %% [markdown]
# ## Exporting to R?
#
# It is **almost** ready. R will use the new layer and the location of the points. However, R's ggplot needs NOT your size variable. Give GGPLOT the _population_ variables and use **scale_size_area()** to manage the size and the legend.
#
# Also, notice that I have the country names as index, and the other columns might be redundant (they are in **Africa_8857**):

# %%
Africa_8857_symbols.head()
# Out:
#          iso2 iso3  region  fragility        co2    sq_km  num_airports  \
# Country
# ALGERIA    DZ  DZA  AFRICA       75.4  151633000  2381740            95
# ANGOLA     AO  AGO  AFRICA       87.8   19362000  1246700           107
# BOTSWANA   BW  BWA  AFRICA       59.5    5965000   581730           122
# BENIN      BJ  BEN  AFRICA       73.6    6903000   112622            10
# BURUNDI    BI  BDI  AFRICA       98.2     715000    27830             6
#
#           population   mobiles                          geometry       size  \
# Country
# ALGERIA     47022473  51500000     POINT (58149.408 3504624.452)  18.366454
# ANGOLA      37202061  25700000  POINT (1789934.856 -1524650.389)  16.442654
# BOTSWANA     2450668   4440000  POINT (2262432.346 -2828174.988)   4.888440
# BENIN       14697052  16400000     POINT (219186.939 1191134.38)  10.686611
# BURUNDI     13590102   8650000    POINT (2865100.606 -433659.14)  10.312132
#
#           population_outlier
# Country
# ALGERIA                    0
# ANGOLA                     0
# BOTSWANA                   0
# BENIN                      0
# BURUNDI                    0

# %%
## then
Africa_8857_symbols.reset_index(drop=False, inplace=True)
Africa_8857_symbols.drop(columns=['iso2', 'region', 'fragility', 'co2', 'sq_km', 'num_airports','mobiles'], inplace=True)

## final for R:
Africa_8857_symbols.head()
# Out:
#     Country iso3  population                          geometry       size  \
# 0   ALGERIA  DZA    47022473     POINT (58149.408 3504624.452)  18.366454
# 1    ANGOLA  AGO    37202061  POINT (1789934.856 -1524650.389)  16.442654
# 2  BOTSWANA  BWA     2450668  POINT (2262432.346 -2828174.988)   4.888440
# 3     BENIN  BEN    14697052     POINT (219186.939 1191134.38)  10.686611
# 4   BURUNDI  BDI    13590102    POINT (2865100.606 -433659.14)  10.312132
#
#    population_outlier
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# Done!

# %% [markdown]
# # Thematics: Choropleths
#
# Notice that we do not normalized DDMs nor PSMs: data is just a count or a representation of counts. Choropleths will 'paint' the whole polygon and as noticed in PSMs, we have to be very careful when using color in shape, as the area itself is a confounding. To control this visual artifact, the variable must be normalized, that is, divided by a value correlated with the area.
#
# Then, for this course, a choropleth is a normalized representation of data.
#
# Following our definition:
#
# * This is **NOT** a choropleth:

# %%
Africa_8857.plot(Africa_8857.population,cmap="YlOrRd")
# Out:
# <Axes: >

# %% [markdown]
# ### Preprocessing: Normalization

# %% [markdown]
# * This **IS** a choropleth:

# %%
Africa_8857.plot(Africa_8857.population/Africa_8857.sq_km,cmap="YlOrRd")
# Out:
# <Axes: >

# %% [markdown]
# Choropleths are great to represent normalized indicators such as:
# * Densities
# * Proportion
# * Ratios
# * Averages
#
# This is a density:

# %%
Africa_8857['population_density']=Africa_8857.population/Africa_8857.sq_km

# %% [markdown]
# ### Preprocessing: Discretizing

# %% [markdown]
# Population by area is a density indicator. This is a real number (not an integer), so most of the time the color gradient might  not be that useful to reveal some pattern visually. Then, we often discretize (or bin) the indicator computed.
# Now, we want to cut the variable. Run the next code to make sure you have tose packages:

# %%
## do you have these installed?
 #! pip show numba mapclassify numpy

# %% [markdown]
# Let's explore the bining algorithms:

# %%
import mapclassify
import numpy as np

np.random.seed(12345) # so we all get the same results!

# let's try 5 intervals
K=5
theVar=Africa_8857['population_density']

# same interval width, easy interpretation
ei5 = mapclassify.EqualInterval(theVar, k=K)
# same interval width based on standard deviation, easy - but not as the previous one, poor when high skewness
msd = mapclassify.StdMean(theVar)
# interval width varies, counts per interval are close, not easy to grasp, repeated values complicate cuts
q5=mapclassify.Quantiles(theVar,k=K)

# based on similarity, good for multimodal data
mb5 = mapclassify.MaximumBreaks(theVar, k=K)
# based on similarity, good for skewed data
ht = mapclassify.HeadTailBreaks(theVar) # no K needed
# based on similarity, optimizer
fj5 = mapclassify.FisherJenks(theVar, k=K)
# based on similarity, optimizer
jc5 = mapclassify.JenksCaspall(theVar, k=K)
# based on similarity, optimizer
mp5 = mapclassify.MaxP(theVar, k=K)

# %% [markdown]
# How can we select the right classification?
# Let me use the the Absolute deviation around class median (ADCM) to make the comparisson:

# %%
class5 = ei5,msd, q5,mb5,  ht, fj5, jc5, mp5
# Collect ADCM for each classifier
fits = np.array([ c.adcm for c in class5])
# Convert ADCM scores to a DataFrame
adcms = pd.DataFrame(fits)
# Add classifier names
adcms['classifier'] = [c.name for c in class5]
# Add column names to the ADCM
adcms.columns = ['ADCM', 'Classifier']

# %% [markdown]
# Now, plot the **adcms**:

# %%
adcms.sort_values('ADCM').plot.barh(x='Classifier')
# Out:
# <Axes: ylabel='Classifier'>

# %% [markdown]
# Let's save the best strategy:

# %%
Africa_8857['population_density_FJ5'] = fj5.yb # yb will give you a numeric label

# %%
# there you are
Africa_8857[['population_density','population_density_FJ5']].head(20)
# Out:
#     population_density  population_density_FJ5
# 2            19.742908                       0
# 6            29.840428                       0
# 12            4.212724                       0
# 19          130.498943                       1
# 26          488.325620                       3
# 29           14.870401                       0
# 31           17.829430                       0
# 32           49.215358                       0
# 35           65.131468                       0
# 36          402.747651                       3
# 40            9.070790                       0
# 42          151.503595                       1
# 45           42.886810                       0
# 48          111.086173                       1
# 50           64.020320                       0
# 53          107.353344                       1
# 58          223.303274                       2
# 59            9.172236                       0
# 61          145.007575                       1
# 66           56.887455                       0

# %% [markdown]
# We could create a copy of that column to add descriptive labels:

# %%
# renaming
newLabelsForLevels={0:"0_VeryLow", 1:"1_Low", 2:"2_Middle", 3:"3_High", 4:"4_VeryHigh"}

Africa_8857['population_density_FJ5_cat']=Africa_8857.loc[:,'population_density_FJ5'].replace(newLabelsForLevels)

# we have
Africa_8857[['population_density','population_density_FJ5','population_density_FJ5_cat']].head(20)
# Out:
#     population_density  population_density_FJ5 population_density_FJ5_cat
# 2            19.742908                       0                  0_VeryLow
# 6            29.840428                       0                  0_VeryLow
# 12            4.212724                       0                  0_VeryLow
# 19          130.498943                       1                      1_Low
# 26          488.325620                       3                     3_High
# 29           14.870401                       0                  0_VeryLow
# 31           17.829430                       0                  0_VeryLow
# 32           49.215358                       0                  0_VeryLow
# 35           65.131468                       0                  0_VeryLow
# 36          402.747651                       3                     3_High
# 40            9.070790                       0                  0_VeryLow
# 42          151.503595                       1                      1_Low
# 45           42.886810                       0                  0_VeryLow
# 48          111.086173                       1                      1_Low
# 50           64.020320                       0                  0_VeryLow
# 53          107.353344                       1                      1_Low
# 58          223.303274                       2                   2_Middle
# 59            9.172236                       0                  0_VeryLow
# 61          145.007575                       1                      1_Low
# 66           56.887455                       0                  0_VeryLow

# %% [markdown]
# We are ready for a discrete choropleth:

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(1, figsize=(10, 10))
Africa_8857.plot(column='population_density_FJ5_cat', # variable to plot
                 cmap='viridis_r', # set of colors
                 categorical=True, # can be interpreted as category
                 edgecolor='grey', # border color
                 linewidth=0.3, # width of border
                 legend=True, # need a legend?
                 ax=ax
       )

ax.set_axis_off()

# %% [markdown]
# # Saving
#
# Let's save these maps for R.

# %%
## Good practice to refresh your memory

## Find only GeoDataFrames in the current session
geodataframe_list = [var for var in globals() if isinstance(globals()[var], gpd.GeoDataFrame)]

print("List of GeoDataFrames in memory:")
for name in geodataframe_list:
    print(name)
# Out:
# List of GeoDataFrames in memory:
# countries
# _10
# theMapAndData
# _14
# Africa
# temporal_gdf
# _19
# _20
# Africa_dots
# _25
# Africa_8857
# Africa_dots_8857
# _31
# _32
# Africa_8857_symbols
# _36
# _38
# _48
# _50
# _51

# %% [markdown]
# These are the ones needed in R:

# %%
# for choropleth and base map
Africa_8857.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 52 entries, 2 to 169
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     52 non-null     object
#  1   iso2                        51 non-null     object
#  2   iso3                        52 non-null     object
#  3   region                      52 non-null     object
#  4   fragility                   52 non-null     float64
#  5   co2                         52 non-null     int64
#  6   sq_km                       52 non-null     int32
#  7   num_airports                52 non-null     int32
#  8   population                  52 non-null     int32
#  9   mobiles                     52 non-null     int32
#  10  geometry                    52 non-null     geometry
#  11  population_density          52 non-null     float64
#  12  population_density_FJ5      52 non-null     int64
#  13  population_density_FJ5_cat  52 non-null     object
# dtypes: float64(2), geometry(1), int32(4), int64(2), object(5)
# memory usage: 5.3+ KB

# %%
# for DDMs
Africa_dots_8857.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 58615 entries, 0 to 58614
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   geometry  58615 non-null  geometry
# dtypes: geometry(1)
# memory usage: 458.1 KB

# %%
# for PSMs
Africa_8857_symbols.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             52 non-null     object
#  1   iso3                52 non-null     object
#  2   population          52 non-null     int32
#  3   geometry            52 non-null     geometry
#  4   size                52 non-null     float64
#  5   population_outlier  52 non-null     int64
# dtypes: float64(1), geometry(1), int32(1), int64(1), object(2)
# memory usage: 2.4+ KB

# %% [markdown]
# The file **africa_8857.gpkg** will keep all those maps as layers!

# %%
Africa_8857.to_file("africa_8857.gpkg",driver='GPKG',layer='continent')
Africa_dots_8857.to_file("africa_8857.gpkg",driver='GPKG',layer='population_ddm')
Africa_8857_symbols.to_file("africa_8857.gpkg",driver='GPKG',layer='population_psm')

# %% [markdown]
# Take a look at the [Dashboard](https://dacss-spatial.github.io/The-Thematics/draft_storyboard_tabs.html)
